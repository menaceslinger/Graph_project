# %%
#!pip install networkx==2.5

# %%
#!pip install tqdm
#!lscpu

# %%
import numpy as np

# %%
import networkx as nx

# %%
G=nx.cycle_graph(8)
G.add_edges_from([(0,2),(1,3),(2,4),(3,5),(4,6),(5,7),(7,1),(6,0)])
pos = nx.circular_layout(G)
nx.draw(G, pos=pos, node_color="blue")  # Draw the original graph
# Draw a subgraph, reusing the same node positions
nx.draw(G.subgraph([1,2,5,6]), pos=pos, node_color="red")

# %%
G=nx.cycle_graph(8)
G.add_edges_from([(0,2),(1,3),(2,4),(3,5),(4,6),(5,7),(7,1),(6,0)])
pos = nx.circular_layout(G)
nx.draw(G, pos=pos, node_color="red")  # Draw the original graph
# Draw a subgraph, reusing the same node positions
nx.draw(G.subgraph([1,2,5,6]), pos=pos, node_color="blue")

# %%
import pickle
