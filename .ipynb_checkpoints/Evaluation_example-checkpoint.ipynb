# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import networkx as nx
from networkx.algorithms import community
# pip install netgraph
from netgraph import Graph
import evaluate as ev
from networkx.algorithms import community
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
random_graph_test=nx.random_partition_graph([3, 5, 4,5], 0.9, 0.1)
#random_graph_test1 = nx.complete_graph(9)
#random_graph_test2 = nx.path_graph(3)

# %%
nx.draw(random_graph_test)

# %%
clustering=community.label_propagation_communities(random_graph_test)

# %%
cutratio = ev.cut_ratio(random_graph_test,clustering)
avg_internal_density= ev.avg_internal_density(random_graph_test,clustering)
coverage, performance = ev.cov_per(random_graph_test,clustering)

# %%
print(cutratio, avg_internal_density, coverage, performance)
# Out:
# 0.09523809523809523 0.8222222222222223 0.8333333333333334 0.7794117647058824

# %% [markdown]
# On complete graph

# %%
random_graph_test = nx.complete_graph(9)

# %%
nx.draw(random_graph_test)

# %%
clustering=community.label_propagation_communities(random_graph_test)
cutratio = ev.cut_ratio(random_graph_test,clustering)
avg_internal_density= ev.avg_internal_density(random_graph_test,clustering)
coverage, performance = ev.cov_per(random_graph_test,clustering)
print(cutratio, avg_internal_density, coverage, performance)
# Out:
# 0 1.0 1.0 1.0

# %% [markdown]
# # On our own data

# %%
savelocG=r"sliced_data/chordal_graphs_first_50_low_density.pickle"
savelocP=r"sliced_data/chordal_properties_first_50_low_density.pickle"

# %%
import pickle
with open(savelocG, "rb") as input_file:
    graphs = pickle.load(input_file)
with open(savelocP, "rb") as input_file:
    properties = pickle.load(input_file)

# %%
for graph in graphs:
    clustering=community.label_propagation_communities(graph)
    cutratio = ev.cut_ratio(graph,clustering)
    avg_internal_density= ev.avg_internal_density(graph,clustering)
    coverage, performance = ev.cov_per(graph,clustering)
    print(f"{cutratio}, {avg_internal_density}, {coverage}, {performance}")
# Out:
# 0, 1.0, 1.0, 1.0
# 0, 0.8666666666666667, 1.0, 0.8666666666666667
# 0, 0.580952380952381, 1.0, 0.580952380952381
# 0, 0.3894736842105263, 1.0, 0.3894736842105263
# 0.09090909090909091, 0.8401515151515151, 0.75, 0.8233333333333334
# 0, 0.3448275862068966, 1.0, 0.3448275862068966
# 0.05303030303030303, 0.6026679841897233, 0.9292929292929293, 0.7294117647058823
# 0.032, 0.43547619047619046, 0.930635838150289, 0.6717948717948717
# 0, 0.2696969696969697, 1.0, 0.2696969696969697
# 0.062370062370062374, 0.6095399698340875, 0.8375634517766497, 0.8081632653061225
# 0.031914893617021274, 0.6692483660130719, 0.9069767441860465, 0.8134680134680135
# 0.024305555555555556, 0.7127747252747253, 0.9021739130434783, 0.707909604519774
# 0.03278688524590164, 0.6117486338797814, 0.9810874704491725, 0.31298076923076923
# 0.049777777777777775, 0.4066666666666666, 0.8895463510848126, 0.629399585921325
# 0.0291005291005291, 0.4715367965367965, 0.8605898123324397, 0.8371171171171171
# 0.02369980250164582, 0.5266335814722911, 0.8666666666666667, 0.8329113924050633
# 0.04591265397536394, 0.6175377736663583, 0.8407766990291262, 0.7240896358543417
# 0.022727272727272728, 0.6412687399967696, 0.8945686900958466, 0.6933832709113608
# 0.03283302063789869, 0.5687476150229935, 0.8955696202531646, 0.7872340425531915
# 0.022083333333333333, 0.6856514913657771, 0.9236545682102628, 0.7276767676767677
# 0.025678650036683785, 0.5564834915538182, 0.914004914004914, 0.7373626373626374
# 0.022758152173913044, 0.5467321843098241, 0.8784153005464481, 0.7134278565471226
# 0.018072289156626505, 0.4693041911791912, 0.8658064516129033, 0.7565217391304347
# 0.020693675313319733, 0.44683035888515343, 0.9170560747663551, 0.6570028011204482
# 0.036231884057971016, 0.6032568880394967, 0.8984302862419206, 0.539741935483871
# 0.04551820728291316, 0.46063368749127265, 0.847036328871893, 0.7884317233154442
# 0.023266856600189935, 0.6123788624160925, 0.8811188811188811, 0.6939745715865119
# 0.03188683768880365, 0.7159947587930817, 0.7639405204460966, 0.8723535457348407
# 0.03990901571546733, 0.577080942793017, 0.8246445497630331, 0.8284482758620689
# 0.02040816326530612, 0.6509989029454208, 0.8842268842268842, 0.789351230425056
# 0.005662891405729514, 0.4293894409683883, 0.9474835886214442, 0.6777545035609551
# 0.004281949934123847, 0.6299889959664396, 0.9195688225538972, 0.8586477987421384
# 0.025573192239858905, 0.5606523050588, 0.8834134615384616, 0.7526237989652623
# 0.028772753963593658, 0.46019181766005723, 0.848414539829853, 0.881935259310825
# 0.00819672131147541, 0.3998767522933974, 0.9482269503546099, 0.7677504105090311
# 0.014056881333769205, 0.46212021872827647, 0.930186170212766, 0.6240223463687151
# 0.01716581446311176, 0.3165869951584237, 0.9600170140365801, 0.44882491186839013
# 0.011195001301744337, 0.5380710901222824, 0.8939580764488286, 0.8630465051517683
# 0.015342250196695516, 0.5541792695862399, 0.9135169762972454, 0.8990219402590537
# 0.004638031861262351, 0.37083136109638004, 0.9043784599899346, 0.7789949748743719
# 0.021272024065320156, 0.489645828404224, 0.9595422966898243, 0.33012912482066
# 0.0215183752417795, 0.5003010846831072, 0.8969567538707955, 0.7912508544087491
# 0.0169424743892829, 0.4848593392083893, 0.8351389543099388, 0.8181699630515106
# 0.006860071080254567, 0.6195664049454488, 0.9266360983743226, 0.7955583229555833
# 0.030460858585858584, 0.5245001482783438, 0.8887008040626323, 0.8013095238095238
# 0.003582202111613876, 0.6582310723666434, 0.8372591006423983, 0.8260489842415037
# 0.01102158710854363, 0.3478108631009733, 0.8807045636509208, 0.7661756683033278
# 0.0134886572654813, 0.48481281894167116, 0.8931818181818182, 0.805439330543933
# 0.01904520060944642, 0.6075001195677506, 0.7938405797101449, 0.8691535630645701
# 0.022912885662431944, 0.5085845692303013, 0.8316909735908553, 0.8636787148594377
