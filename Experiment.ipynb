# %%
import networkx as nx
from networkx.generators.community import connected_caveman_graph
from networkx.generators.community import relaxed_caveman_graph

# %%
G = nx.connected_caveman_graph(5, 10)

# %%
nx.draw(G)

# %%
G = nx.relaxed_caveman_graph(10, 10, 0.2, seed=42)
nx.draw(G)

# %%
G = nx.gaussian_random_partition_graph(50, 10, 10, 0.9, 0.05)
nx.draw(G)
