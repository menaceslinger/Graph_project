# %%
#!pip install networkx==2.5

# %%
#!pip install tqdm
# !lscpu
# Out:
# Architecture:          x86_64
# CPU op-mode(s):        32-bit, 64-bit
# Byte Order:            Little Endian
# CPU(s):                48
# On-line CPU(s) list:   0-47
# Thread(s) per core:    1
# Core(s) per socket:    24
# Socket(s):             2
# NUMA node(s):          2
# Vendor ID:             GenuineIntel
# CPU family:            6
# Model:                 85
# Model name:            Intel(R) Xeon(R) Gold 6248R CPU @ 3.00GHz
# Stepping:              7
# CPU MHz:               1313.781
# CPU max MHz:           3000.0000
# CPU min MHz:           1200.0000
# BogoMIPS:              6000.00
# Virtualization:        VT-x
# L1d cache:             32K
# L1i cache:             32K
# L2 cache:              1024K
# L3 cache:              36608K
# NUMA node0 CPU(s):     0-23
# NUMA node1 CPU(s):     24-47
# Flags:                 fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm constant_tsc art arch_perfmon pebs bts rep_good nopl xtopology nonstop_tsc aperfmperf eagerfpu pni pclmulqdq dtes64 monitor ds_cpl vmx smx est tm2 ssse3 sdbg fma cx16 xtpr pdcm pcid dca sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave avx f16c rdrand lahf_lm abm 3dnowprefetch epb cat_l3 cdp_l3 invpcid_single intel_ppin intel_pt ssbd mba ibrs ibpb stibp ibrs_enhanced tpr_shadow vnmi flexpriority ept vpid fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm cqm mpx rdt_a avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 cqm_llc cqm_occup_llc cqm_mbm_total cqm_mbm_local dtherm arat pln pts pku ospke avx512_vnni md_clear spec_ctrl intel_stibp flush_l1d arch_capabilities

# %%
from tqdm import tqdm

# %%
import sage.all
import numpy as np

# %%
import networkx as nx

# %%
from sage.graphs.generators.random import RandomUnitDiskGraph
from sage.misc.randstate import current_randstate
seed = current_randstate().seed()

# %%
#Generates Chordal Graphs and converts them into networkx object
np.set_printoptions(suppress=True)
def generate_graph(start, end, step):
    graphs = []
    total=(np.floor(end/step).astype(int))
    properties = []
    avg_degree=0
    avg_density=0
    num_of_nodes=start
    for i in tqdm(range(total)):
        T = RandomUnitDiskGraph(num_of_nodes, radius=.5, side=1, seed=seed)
        ng = T.networkx_graph()
        if (nx.is_connected(ng)):
            #nx.draw(ng)
            graphs.append(ng)
            val = np.array([num_of_nodes, ng.number_of_edges(), average_degree(ng), nx.density(ng)])
            properties.append(val)
            avg_degree+=average_degree(ng)
            avg_density+=nx.density(ng)
            num_of_nodes+=step
    return graphs, properties,avg_degree/len(graphs),avg_density/len(graphs)

# %%
def average_degree(G):
    sum_of_degrees=sum(dict(G.degree).values())
    num_of_nodes=G.number_of_nodes()
    avg_degree=sum_of_degrees/num_of_nodes
    return avg_degree

# %%
graphs, properties,avg_degree,avg_density = generate_graph(5, 2000, 5) #start, end, step
print(avg_degree)
print(avg_density)
# Out:
# 100%|██████████| 400/400 [07:32<00:00,  1.13s/it]
# 479.11482217934065
# 0.4761032493808901

# %%
len(graphs)
# Out:
# 400

# %%
nx.draw(graphs[2])
print(properties[2])
# Out:
# [15.         45.          6.          0.42857143]

# %%
import pickle

# %%
with open("unitd_graphs_first_400(step_5).pkl", "wb") as fp:
    pickle.dump(graphs, fp)
with open("unitd_properties_first_400(step_5).pkl", "wb") as fp:
    pickle.dump(properties, fp)

# %%
graphs2, properties2,avg_degree2,avg_density2 = generate_graph(2000, 2000, 5) #start, end, step
print(avg_degree2)
print(avg_density2)
# Out:
#  64%|██████▍   | 257/400 [1:07:35<24:05, 10.11s/it]

# %%
with open("unitd_graphs_later_400(step_5).pkl", "wb") as fp:
    pickle.dump(graphs2, fp)
with open("unitd_properties_later_400(step_5).pkl", "wb") as fp:
    pickle.dump(properties2, fp)
