# %% [markdown]
# ## Highly Connected subgrph (HCS) Implementation

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from hcs_module import create_example_graph, HCS, draw_graph

if __name__ == "__main__":
    n = create_example_graph()
    clustered = HCS(n.copy())
    #labels = labelled_HCS(n)

    print(clustered)
    draw_graph(n)
    draw_graph(clustered)
# Out:
# Graph with 12 nodes and 17 edges
